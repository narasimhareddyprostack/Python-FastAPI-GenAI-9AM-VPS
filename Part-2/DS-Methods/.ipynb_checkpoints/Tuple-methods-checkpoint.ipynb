# %%
t1=()
t2=tuple()
t3=10,20,30
t4=(10,20,30,40)
enames=("Rahul","Sonia","Priyanka","Modi")
print(type(t1))
print(type(t2))
print(type(t3))
print(type(t4))
print(type(enames))
# Out:
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>

# %%
enames=("Rahul","Sonia","Priyanka","Modi")
for ename in enames:
    print(ename)
# Out:
# Rahul
# Sonia
# Priyanka
# Modi

# %%
enames=("Rahul","Sonia","Priyanka","Modi")
index=0
while index<=len(enames)-1:
    print(enames[index])
    index=index+1
# Out:
# Rahul
# Sonia
# Priyanka
# Modi

# %%
a = (1,2,3)
#a+=(4,5,6)
a = a+(4,5,6)
print(a)
print(a is a)
# Out:
# (1, 2, 3, 4, 5, 6)
# True

# %%
numbers=(10,20,30,40)
#numbers.append(50)
numbers.eat(50)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 3
#       1 numbers=(10,20,30,40)
#       2 #numbers.append(50)
# ----> 3 numbers.eat(50)
#
# AttributeError: 'tuple' object has no attribute 'eat'
