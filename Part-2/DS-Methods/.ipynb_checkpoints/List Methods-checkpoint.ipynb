# %%
l1=[]
l2=list()
eids=[101,102,103,104]
print(l1)
print(l2)
print(eids)
print(type(l1))
print(type(l2))
print(type(eids))
# Out:
# []
# []
# [101, 102, 103, 104]
# <class 'list'>
# <class 'list'>
# <class 'list'>

# %%
elements=[10,20.5,True,"Rahul",[],(),{10}]
print(elements)
# Out:
# [10, 20.5, True, 'Rahul', [], (), {10}]

# %%
numbers=[10,20,10,30,40,20,20]
print(numbers)
for number in numbers:
    print(number)
# Out:
# [10, 20, 10, 30, 40, 20, 20]
# 10
# 20
# 10
# 30
# 40
# 20
# 20

# %%
numbers=[10,20,10,30,40,20,20]
i=0
while i<=len(numbers)-1:
    print(numbers[i])
    i=i+1
# Out:
# 10
# 20
# 10
# 30
# 40
# 20
# 20

# %%
numbers=[10,20,10,30,40,20,20]
#list.count(ele) - return no of occorances of specified element
print(numbers.count(20))  #3
#list.index(ele)  - return index value of first occurance of specified elemnt
print(numbers.index(10))  #0
# Out:
# 3
# 0

# %%
#update 
numbers=[100,200,300,400]
numbers.append(500) #add element end of list
print(numbers)
numbers.insert(1,150)
print(numbers)
numbers.insert(800,800)
print(numbers)
print(len(numbers))
# Out:
# [100, 200, 300, 400, 500]
# [100, 150, 200, 300, 400, 500]
# [100, 150, 200, 300, 400, 500, 800]
# 7

# %%
a=[10,20,30]
b=[30,40,50]
a.extend(b)
print(a)
# Out:
# [10, 20, 30, 30, 40, 50]

# %%
#delete
enames=["Rahul","Sonia","Priyanka","Modi"]
enames.remove("Sonia")
print(enames)
enames.remove("RK")
print(enames)
# Out:
# ['Rahul', 'Priyanka', 'Modi']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 5
#       3 enames.remove("Sonia")
#       4 print(enames)
# ----> 5 enames.remove("RK")
#       6 print(enames)
#
# ValueError: list.remove(x): x not in list

# %%
enames=["Rahul","Sonia","Priyanka","Modi"]
enames.clear()
print(enames)
# Out:
# []

# %%
enames=["Rahul","Sonia","Priyanka","Modi"]
del enames
print(enames)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 3
#       1 enames=["Rahul","Sonia","Priyanka","Modi"]
#       2 del enames
# ----> 3 print(enames)
#
# NameError: name 'enames' is not defined
